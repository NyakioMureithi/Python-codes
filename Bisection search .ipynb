# %%
import math
print('\033[1m'+"Welcome to guessing game"+'\033[0m')#'\033[1m' used to bold the text
    #print("Please think of a number between {} and {}".format(low, high))#Gives the range to user
try:
    high= int(input("Please choose your upper limit"))#age as an integer
    if 0<=high<1000000:
        print("Your upper limit is {}".format(high)) #%d (d-digit) is a place holder to allow for dynamic values
    else:
        print("Must be below 1000,000!")
    #alt print("I see that you are {} years old".format(age))
except ValueError:
    print("Hey, that wasn't a number")
    high= int(input("Please choose your upper limit"))#age as an integer
    if 0<=high<1000000:
        print("Your upper limit is {}".format(high)) #%d (d-digit) is a place holder to allow for dynamic values
    else:
        print("Must be below 1000,000!")

try:
    low= int(input("Please choose your lower limit"))#age as an integer
    if 0<=low<1000000:
        print("Your lower limit is {}".format(low)) #%d (d-digit) is a place holder to allow for dynamic values
    else:
         print("Must be below 1000,000!")
        #alt print("I see that you are {} years old".format(age))
except ValueError:
    print("Hey, that wasn't a number")
    low= int(input("Please choose your lower limit"))#age as an integer
    if 0<=low<1000000:
        print("Your lower limit is {}".format(low)) #%d (d-digit) is a place holder to allow for dynamic values
    else:
         print("Must be below 1000,000!")
        #alt print("I see that you are {} years old".format(age))

ans = math.ceil((high+low)/2)
k=math.ceil(math.log((high-low),2))
print("Is your secret number %s?"%ans)#First guess
k=k-1#count=count-1
print("Counts left are:",k)
guess = input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c.")

while (k>0):
    if guess.lower()== "c":
        #guess= input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c.")
        k=k-1#count=count-1
        print("Counts left are:",k)
    break
    
    if guess.lower()== "h": 
        high = ans
        ans = math.ceil((high+low)/2)
        print("Is your secret number {}?".format(ans))
        guess= input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c.")
        k=k-1#count=count-1
        print("Counts left are:",k)

    elif guess.lower()== "l": 
        low = ans
        ans =math.ceil((high+low)/2)
        print("Is your secret number {}?".format(ans))
        guess = input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c.")
        k=k-1#count=count-1
        print("Counts left are:",k)
    else:
        print("You have indicated a wrong letter")
        guess = input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c.")
#print("Counts left are:",k)
print("Game over. Your secret number was:{}".format(ans))
# Out:
# Welcome to guessing game
# Please choose your upper limit300
# Your upper limit is 300
# Please choose your lower limit100
# Your lower limit is 100
# Is your secret number 200?
# Counts left are: 7
#  Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c.c
# Counts left are: 6
# Game over. Your secret number was:200

# %%
import math
while True:
    try:
        high=int(input('please enter the upper limit'))
        low=int(input('please enter the lower limit'))
        if high>low:
            ans=math.ceil(high+low)/2
            k=math.ceil(math.log((high-low),2))
            print('is your answer {}'.format(ans))
            guess=str(input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c."))
            if guess.lower()=='c':
                k=k-1
                print('{} counts left'.format (k))
                print('YEEEEEE!')
                guess=str(input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c."))
            elif guess.lower()=='h':
                high=ans
                ans=math.ceil(high+low)/2
                print('is your answer {}'.format(ans))
                guess=str(input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c."))
            elif guess.lower()=='c':
                low=ans
                ans=math.ceil(high+low)/2
                print('is your answer {}'.format(ans))
                guess=str(input(" Is the guess high? please press h. is the guess low? please press l. Is the guess correct? please press c."))
                continue
        else:
            print('the higher must be greater than the lower')
            continue
    except ValueError:
        print('Enter number')
