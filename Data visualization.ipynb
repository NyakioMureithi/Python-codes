# %% [markdown]
# # Data Visualization-Matplotlib

# %% [markdown]
# ## Line Graphs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('Randoms numbers')
plt.show
plt.title('Graph 1')
# Out:
# Text(0.5, 1.0, 'Graph 1')

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel('Numbers')
plt.ylabel('Randoms')
plt.title('Graph 2')
# Out:
# Text(0.5, 1.0, 'Graph 2')

# %% [markdown]
# ##NB// df1['Dates']=pd.to_datetime(df1.Dates)#NB Matplot cant plot the dates in the standard date format instead chage to datetime.date which can be achieved by converting to an object array

# %%
import matplotlib.pyplot as plt
import pandas as pd
df1=pd.DataFrame({'Dates':['2016/10/3','2016/10/4','2016/10/5','2016/10/6','2016/10/7'],'Open':[774.25,776.030029,779.309998,779,779.659973],'High':[776.065002,778.710022,782.070007,780.47998,779.659973],'Low':[769.5,772.890015,775.650024,775.539978,770.75],'Close':[772.559998,776.429993,776.469971,776.859985,775.080017]})
#df1['Dates']=pd.to_datetime(df1.Dates)#NB Matplot cant plot the dates in the standard date format instead chage to datetime.date which can be achieved by converting to an object array 
plt.figure()
df1.plot()
fig.autofmt_xdate()

plt.xlabel('Dates')
plt.ylabel('Values')
plt.title('Graph 3')
# Out:
# Text(0.5, 1.0, 'Graph 3')

# %%
df1
# Out:
#        Dates        Open        High         Low       Close
# 0  2016/10/3  774.250000  776.065002  769.500000  772.559998
# 1  2016/10/4  776.030029  778.710022  772.890015  776.429993
# 2  2016/10/5  779.309998  782.070007  775.650024  776.469971
# 3  2016/10/6  779.000000  780.479980  775.539978  776.859985
# 4  2016/10/7  779.659973  779.659973  770.750000  775.080017

# %%
import pandas as pd 
import numpy as np
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

ts.plot()

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=list('ABCD'))
df=df.cumsum()
plt.figure()#Creates a figure object used when we want to tweak the size of the figure and when using multiple axes object on a single figure
df.plot()

# %%
#Pandas has a range of inbuilt functions for generating fixed-frequency dates and time span
dates= pd.date_range('2018-01-01', periods=3, freq='M')# D-day,H-hour, M-month

dates
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-31'], dtype='datetime64[ns]', freq='M')

# %%
#Generating 1000 dates with a freq of daily
index=ts.index
index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
# Bar Graphs
import matplotlib.pyplot as plt;plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects=('pyrhon','C++','Java','Perl','Scala','Lisp')
y_pos=np.arange(len(objects))
performance=[10,3,5,6,7,9]

plt.bar(objects,performance, align='center',alpha=0.5)
#plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.show()

# %%
# Horizontal Bar Graphs(barh)
# %matplotlib inline
import matplotlib.pyplot as plt;plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects=('python','C++','Java','Perl','Scala','Lisp')
y_pos=np.arange(len(objects))
performance=[10,3,5,6,7,9]

plt.barh(objects,performance, align='center',alpha=0.5)
plt.title('Horizontal Bar')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

lang=['pyrhon','C++','Java','Perl','Scala','Lisp']
popularity=[22.2,17.6,8.8,8,7.7,6.7]

plt.bar(lang,popularity)#(x,y)
plt.title('Bar Chart 1')
plt.xlabel('Language')
plt.ylabel('Popularity')
# Out:
# Text(0, 0.5, 'Popularity')

# %%
#First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

#Creates just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

#Creates two subplots and unpacks the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

#Creates four polar axes, and accesses them through the returned array
fig, axes = plt.subplots(2, 2, subplot_kw=dict(polar=True))
axes[0, 0].plot(x, y)
axes[1, 1].scatter(x, y)

#Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')

#Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

#Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

#Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

#Creates figure number 10 with a single subplot
#and clears it if it already exists.
fig, ax=plt.subplots(num=10, clear=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
#Inputs
n=4
means_frank=(90,55,40,65)
means_tim=(90,55,40,65)
#create plot
fig, ax=plt.subplots()
index=np.arange(n)
bar_width=0.35
opacity=0.8

rects1=plt.bar(index, means_frank, bar_width, alpha=opacity, color='b', label='Frank')

rects2=plt.bar(index+bar_width,means_tim,bar_width,alpha=opacity,color='g',label='Tim')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Bar 3')


plt.tight_layout()
plt.show()

# %%
n=4
index=np.arange(4)
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c948c2e75780> in <module>
#       1 n=4
# ----> 2 index=np.arange(4)
#       3 index
#
# NameError: name 'np' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
plt.plot(x,y,'r-')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
plt.subplot(1,2,2)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# # OBJECT ORIENTED METHOD

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])#A method to add a set of axis
axes.plot(x,y)
axes.set_xlabel('X label')

axes.set_xlabel('y label')
# Out:
# Text(0.5, 0, 'y label')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('Larger plot')
axes2.plot(y,x,'r')
axes2.set_title('Smaller plot')
# Out:
# Text(0.5, 1.0, 'Smaller plot')

# %%
fig,axes=plt.subplots()
axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %% [markdown]
# # Figure Size and DPI

# %%
fig=plt.figure(figsize=(3,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
#Saving a figure
fig.savefig('my_picture.png',dpi=200)#you can set the dpi(size at this stage as shown)

# %%
#Adding legend to a figure
fig=plt.figure()
ax=fig.add_axes(0,0,1,1)
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X cubic')

ax.legend(loc=0)

# %% [markdown]
# # Plot Appearance

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=5,alpha=0.5,ls='-.')
#alpha determines the opacity of the graph.
#line width is lw
#line style(--,-.,:,steps)>ls
#marker show the intersection of x,y

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=5,alpha=0.5,marker='*',markersize=10,
       markeredgecolor='black',markerfacecolor='red')
#marker show the intersection of x,y
#marker size,markerfacecolor,markeredgecolor

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=5,alpha=0.5,marker='*',markersize=10,
       markeredgecolor='black',markerfacecolor='red')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)
